# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from time import sleep
import requests
import re
import pandas as pd
import numpy as np
import os

from selenium.webdriver.common.keys import Keys

# %%
name=['농심 신라면']
category=['별점']

#SK매직 식기세척기 후기
ns_address="https://search.shopping.naver.com/catalog/5639964597?query=신라면&NaPm=ct%3Dlajb3eaw%7Cci%3Dd80a0856defa6c576d0412d9fd1c6a7f3fcff6a9%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3D23c2b1c29aa42bc48cda717cba3463105133ccf1"
#xpath
shoppingmall_review="/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul"

# %%
header = {'User-Agent': ''}
d = webdriver.Chrome('./chromedriver-3') # webdriver = chrome
d.implicitly_wait(3)
d.get(ns_address)
req = requests.get(ns_address,verify=False)
html = req.text 
soup = BeautifulSoup(html, "html.parser")
sleep(2)

#쇼핑몰 리뷰 보기
d.find_element(By.XPATH, shoppingmall_review).click()
sleep(2)

element=d.find_element(By.XPATH, shoppingmall_review)
d.execute_script("arguments[0].click();", element)
sleep(2)
# Out:
# /var/folders/1q/bps9yr4940d3198xt1pz1z800000gn/T/ipykernel_43758/4072806480.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   d = webdriver.Chrome('./chromedriver-3') # webdriver = chrome
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'search.shopping.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
def add_dataframe(name,category,reviews,stars,cnt):  #데이터 프레임에 저장
    #데이터 프레임생성
    df1=pd.DataFrame(columns=['type','category','review','star'])
    n=1
    if (cnt>0):
        for i in range(0,cnt-1):
            df1.loc[n]=[name,category,reviews[i],stars[i]] #해당 행에 저장
            i+=1
            n+=1
    else:
        df1.loc[n]=[name,category,'null','null']
        n+=1    
    return df1

# %%
# 리뷰 가져오기
d.find_element(By.XPATH, shoppingmall_review).click() #스크롤 건드리면 안됨
name_=name[0]
category_=category[0]
reviews=[]
stars=[]
cnt=1   #리뷰index
page=1

# %%
while True:
    j=1
    print ("페이지", page ,"\n") 
    sleep(2)
    while True: #한페이지에 20개의 리뷰, 마지막 리뷰에서 error발생
        try:
            star=d.find_element(By.XPATH,'/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul/li[1]/div[1]/span[1]').text
            stars.append(star)
            review=d.find_element(By.XPATH, '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul/li['+str(j)+']/div[2]/div[1]').text
            reviews.append(review)
            if j%2==0: #화면에 2개씩 보이도록 스크롤
                ELEMENT = d.find_element(By.XPATH, '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul/li['+str(j)+']/div[2]/div[1]')
                d.execute_script("arguments[0].scrollIntoView(true);", ELEMENT)       
            j+=1
            print(cnt, review ,star, "\n")
            cnt+=1 
        except: break
            
    sleep(2)
    
    if page<11:#page10
        try: #리뷰의 마지막 페이지에서 error발생
            page +=1
            next_page=d.find_elementfind_element(By.XPATH,'/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a['+str(page)+']').click() 
            
        except: break #리뷰의 마지막 페이지에서 process 종료
        
    else : 
        try: #page11부터
            page+=1
            if page%10==0: next_page=d.find_elementfind_element(By.XPATH,'/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[11]').click()
            else : next_page=d.find_elementfind_element(By.XPATH,'/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a['+str(page%10+2)+']').click()
            
        except: break
            

df4=add_dataframe(name_,category_,reviews,stars,cnt)
#save()
# Out:
# 페이지 2
#
# 1 라면은 일상샹활 필수 식품이죠.. 일주일에 한번이상은
# 라면은 일상샹활 필수 식품이죠..
# 일주일에 한번이상은 먹고 있는 라면이라 늘 여유있게 구비해놓는데 맛있는 신라면 6개입 가격이 너무 좋아서 구매하게 됐답니다..솔직히 예전부터 즐겨먹던 신라면이 어느순간부터 제 입맛이 변한건지 너무 맵게만 느껴져서 한동안 먹지 않았어요..혀끝에 느껴지는 매운맛 때문에 면발의 식감을 느낄 사이도 없이 그냥 삼키게 되고 라면의 진리 국물도 맛 볼수가 없었어요..그래서 요즘 라면 종류가 워낙 많으니깐 그날 기분에 따라 골라 선택해서 신라면만 빼고서 이것저것 갖가지 라면을 다 먹어봤답니다..각각 다른 개성의 라면을 먹으면서 매번 새로운 경험을 하는것도 나쁘지 않았고, 왠만해선 다 맛있었어요..그런데 시간이 지나 몇번정도인지는 세지 않아 잘은 모르겠지만 암튼 어느정도 먹었다 싶으면 조금씩 질리기 시작하더군요..느끼하기도 하고 다 먹지 못하고 꼭 남기게 되고..혹시 나이가 들어 이제 라면이 몸에 받질 않나~ 하는 생각이 들었지만 그게 아니였어요..
# 그동안 먹었던 신라면의 칼칼 개운한 맛을 따라가진 못했던거였어요..또 면발의 담백 탱탱함도 마찬가지구요..그래서 다시 신라면을 구매하기 시작했고 세월따라 걸 잘 못먹게 된듯하여 이제는 다른 라면 3분의 1일 넣고 신라면을 끓여서 먹고 있답니다..
# 신라면의 기본 베이스 맛에 조금은 불편했던 매운맛을 중화시켜 주니 저에겐 딱~!이더군요..
# 오래도록 사랑받는 이유를 알 것 같습니다..
# 라면은 역시 신라면~!! 평점5
#
# 2 저럼할때 평상시 보다 조금 넉넉하게 구입해서 집에 재워
# 저럼할때 평상시 보다 조금 넉넉하게 구입해서 집에 재워놓고 있으면 아주 든든합니다.
# 맛이야 평상시 먹고 있어서 검증된거니 가격만 착하면 소비자로서는 땡큐이지요.
# 착한기업이 생산하고 국민 쇼핑몰 이마트에서 판매하니 소비자 입장에선 안심하고 구매 할 수 있으니 행복한 고민이네요.
# ...

# %%
df4.to_excel('naver_sinlamyun_result.xlsx')
